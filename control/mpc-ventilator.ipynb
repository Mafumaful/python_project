# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

from scipy.optimize import minimize
from math import sin

# %%
plt.rcParams["figure.figsize"] = (20,10)

# %%
# arm radius
r_m = 0.5 # m
m_kg = 4
# arm inertia (dominated by point load at end)
theta = m_kg * r_m ** 2
Fg = m_kg * 9.81
# damper
k = 0.1

## disturbances / plant model
r_real_m = r_m + 0.1 # m
k_real = k + 0.1
angle_noise_std = np.deg2rad(2) # rad
angle_vel_noise_std = np.deg2rad(6) # rad/s
motor_noise_std = 2 # N

def system_dynamics(x, u):  
    x1, x2 = x
    
    dx_dt = [
        x2,
        r_m / theta * (Fg * sin(x1) - u) - k * x2
    ]
    
    return np.array(dx_dt)

def system_dynamics_plant(x, u):  
    x1, x2 = x
    
    # IMU noise
    x1 += np.random.normal(0, angle_noise_std)
    x2 += np.random.normal(0, angle_vel_noise_std)
    # Motor noise
    u += np.random.normal(0, motor_noise_std)
    
    dx_dt = [
        x2,
        (r_real_m) / theta * (Fg * sin(x1) - u) - (k_real) * x2
    ]
    
    return np.array(dx_dt)

assert np.allclose(system_dynamics([np.deg2rad(90), 0], Fg), [0,0])

# %%
x0 = np.array([np.deg2rad(90), 0])

duration_s = 180

# this cant be too small for it to work
delT = 0.01
N = 4
n_steps = int(duration_s / delT)

opti_options = {"maxfun":3}

# %%
x = x0
xs = [x]
us = [0]

u_traj_init = np.ones(N)
u = None

for i in range(n_steps):
    if u is not None:
        # warm start using state similarity
        # initial value embedding
        u_traj_init = u_opt
    
    Q = [
        [4,0],
        [0,1]
    ]
    
    # this has to be very small because we weight N vs radians
    # i.e. if x and u are weighted the same, a relatively small
    # deviation in u of 1N is weighted the same as ~60°
    R = 0.00001
    
    def obj(u_traj):
        xk = x
        
        # single-shooting
        cost = 0
        for k in range(N):
            uk = u_traj[k]
            
            cost += 1/2 * (xk.T @ Q @ xk + uk * R * uk)
            
            xk1 = xk + delT * system_dynamics(xk, uk)
            xk = xk1
        
        return cost
    
    def jac(u_traj):
        return R * u_traj

    res = minimize(obj, u_traj_init, options=opti_options, method="L-BFGS-B")
    
    if not res.success and not "EVALUATIONS EXCEEDS LIMIT" in str(res.message):
        print("optimization failed ", i)
        print(res)
        break
    
    # use first control input
    u_opt = res.x
    u = u_opt[0]
    
    x = x + delT * system_dynamics_plant(x, u)
    
    if i % 100 == 0:
        print(f"In step {i}/{n_steps} u={u:.2f}N, x={x.T}")
        print(res.success)
        print(res.message)
    
    us.append(u)
    xs.append(x)

xs = np.array(xs)
us = np.array(us)
# Out:
# In step 0/18000 u=16.80N, x=[1.57085909 0.12388851]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 100/18000 u=39.48N, x=[ 1.46967437 -0.08138481]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 200/18000 u=38.04N, x=[ 1.37417832 -0.11249163]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 300/18000 u=38.12N, x=[ 1.28103042 -0.08878433]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 400/18000 u=37.19N, x=[ 1.19152835 -0.08143579]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 500/18000 u=37.67N, x=[ 1.12253961 -0.0506254 ]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 600/18000 u=36.70N, x=[ 1.05942475 -0.06125948]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 700/18000 u=33.57N, x=[ 0.99018357 -0.05763515]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 800/18000 u=31.78N, x=[ 0.92331554 -0.06288614]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 900/18000 u=27.50N, x=[ 0.86776397 -0.06051644]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step

# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 15800/18000 u=-1.88N, x=[-0.01958372  0.01612043]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 15900/18000 u=-1.76N, x=[-0.0220111   0.05432161]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 16000/18000 u=-2.02N, x=[-0.01586068 -0.02114641]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 16100/18000 u=-1.49N, x=[-0.01169004  0.0045641 ]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 16200/18000 u=-2.15N, x=[-0.00355192  0.01155986]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 16300/18000 u=0.65N, x=[-0.00985158  0.01876553]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 16400/18000 u=2.05N, x=[0.0041971  0.02680513]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 16500/18000 u=-1.01N, x=[-0.01651224 -0.03000113]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 16600/18000 u=-1.69N, x=[-0.02859272 -0.01758172]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 16700/18000 u=0.77N, x=[-0.01795644  0.00416924]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 16800/18000 u=0.42N, x=[-0.01702744 -0.01116682]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 16900/18000 u=-1.02N, x=[0.00180501 0.0433005 ]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 17000/18000 u=-0.19N, x=[-0.01070096  0.01436615]
# True
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# In step 17100/18000 u=-1.72N, x=[-0.04056061 -0.02499375]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 17200/18000 u=1.85N, x=[-0.02615963  0.01492564]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 17300/18000 u=-1.88N, x=[-0.03730325  0.04563417]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 17400/18000 u=-2.56N, x=[-0.03300132 -0.05028363]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 17500/18000 u=-0.87N, x=[-0.023602   -0.00934315]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 17600/18000 u=-3.25N, x=[-0.02502024  0.01521286]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 17700/18000 u=-0.61N, x=[-0.01568193 -0.03945274]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 17800/18000 u=2.59N, x=[0.00545143 0.03843592]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# In step 17900/18000 u=1.87N, x=[ 0.01010232 -0.05937033]
# False
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT

# %% [markdown]
# ## Video Rendering

# %%
from matplotlib import animation, rc
from IPython.display import HTML

fig, axes = plt.subplots(ncols=3)

axes[0].set_xlim((-2,2))
axes[0].set_ylim((-2,2))
axes[0].set_aspect("equal")
axes[0].set_facecolor("#729fcf")
axes[0].tick_params(left=False,
                bottom=False,
                labelleft=False,
                labelbottom=False)
axes[0].set_title("Visual Simulation")
axes[0].set_anchor("N")
plt.figtext(0.05,0,f"""
Zero-Mean Normal Noise (Std)
x1 (Angle): {np.rad2deg(angle_noise_std):.0f} °
x2 (Angle Velocity): {np.rad2deg(angle_vel_noise_std):.2f} °/s
u (Motor Force): {motor_noise_std:.0f} N
""", fontsize=12, transform=axes[0].transAxes)

axes[1].plot(np.rad2deg(xs[:,0]))
axes[1].set_title("Angle $x_1$ [°]")
oi = axes[1].axvline(0, color="r")

axes[2].plot(us)
axes[2].set_title("Control $u$ [N]")
oi2 = axes[2].axvline(0, color="r")

# center bearing
axes[0].add_artist(plt.Circle([0,0], radius=0.02, color="k"))

line_arm = axes[0].plot([],[], "k")
line_force = axes[0].plot([],[], "r")

def animate(k):
    state = xs[k]
    phi, dphi = state

    r = 0.5
    F = us[k]

    x = r * np.sin(phi)
    y = r * np.cos(phi)

    x_force = x + F * np.cos(phi)
    y_force = y - F * np.sin(phi)

    line_arm[0].set_data([0,x],[0,y])
    line_force[0].set_data([x, x_force],[y, y_force])
    oi.set_xdata(k)
    oi2.set_xdata(k)
    
    return (oi, oi2)

step = round(n_steps/100)
anim = animation.FuncAnimation(fig, animate, frames=np.arange(len(xs)//step) * step, interval=1000//30, blit=True)
HTML(anim.to_html5_video())
# Out:
# <video width="1440" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
anim.save('ventilator-mpc.mp4', codec='h264')
